# %%
from transformers import pipeline

# Load a text generation model
generator = pipeline("text-generation", model="gpt2")

# Input prompt
prompt = "Artificial Intelligence will transform the future of"

# Generate text
outputs = generator(
    prompt,
    max_length=60,
    num_return_sequences=2,
    temperature=0.8,
    top_k=50,
    top_p=0.95,
    do_sample=True
)

# Display generated text
for i, out in enumerate(outputs, 1):
    print(f"--- Generated Text {i} ---")
    print(out["generated_text"])
    print()
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  548MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# [transformers] Passing `generation_config` together with generation-related arguments=({'top_p', 'max_length', 'num_return_sequences', 'do_sample', 'top_k', 'temperature'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=60) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer GPT2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# --- Generated Text 1 ---
# Artificial Intelligence will transform the future of health care. It will revolutionize the way doctors treat patients. It will revolutionize the way they deal with patients. And it will revolutionize how the government functions.
#
# We're talking about a technology that can turn hospitals and doctors into the center of the nation's economy, the place where the doctors and nurses can collaborate and the doctors and nurses can go to work. And it will transform the way doctors treat patients, and it will revolutionize medicine.
#
# It's a great step. And it's going to be a great change for American life. And it's going to be a revolution for America. But it's not going to happen overnight. And it's not going to happen overnight. It's going to happen for a generation. And it's going to happen for the world. And it's going to happen for American life.
#
# And so, you know, these are some of the things that you're going to see. And they're going to happen. They're going to happen. And they're going to happen. And they're going to happen. And they're going to happen. And they're going to happen. And they're going to happen. And they're going to happen. And they're going to happen. And
#
# --- Generated Text 2 ---
# Artificial Intelligence will transform the future of computing by allowing a computer to interact with human brains via neural networks.
#
# In a recent article for Scientific American, researchers from Harvard University and the University of Pennsylvania used a technique called transcranial direct current stimulation (tDCS) to stimulate the brain of a human trying to control an iPhone 4S. The stimulation led the human to be able to control his or her iPhone to navigate a maze.
#
# The researchers found that transcranial direct current stimulation (TDCS) stimulated the brain of a single iPhone 4S running Android 4.0.3 Jelly Bean, enabling the handset to perform various tasks. The researchers said that the TDCS results showed that the iPhone's human brain was able to interact with a specific set of computers in the lab.
#
# "This is a breakthrough," said Dr. David G. Tapp, an assistant professor of neurobiology and neuroscience at Harvard Medical School and an assistant professor of cognitive neuroscience at the University of Pennsylvania and a co-author of the paper. "This is the first time we're able to use TDCS to change the brain's behavior in an effort to understand how our brains work."
#
# Using TDCS, the researchers were able to change the electrical activity of the human brain to
